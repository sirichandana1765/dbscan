# %% [markdown]
# # Exploratory Data Analysis
#
# This notebook provides a starting point for analyzing the Titanic dataset.

# %%
import pandas as pd
from pathlib import Path

data_dir = Path('..') / 'data'
df = pd.read_csv(data_dir / 'train.csv')
df.head()
